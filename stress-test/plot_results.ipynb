# %%
import pandas as pd

# %%
results = pd.read_csv('results.csv')
results
# Out:
#          timeStamp  elapsed      label  responseCode responseMessage  \
# 0    1674926101060      148  Add money           200              OK
# 1    1674926101208      158  Add money           200              OK
# 2    1674926101367      200  Add money           200              OK
# 3    1674926101568      127  Add money           200              OK
# 4    1674926101695      129  Add money           200              OK
# ..             ...      ...        ...           ...             ...
# 527  1674926160475      113  Add money           200              OK
# 528  1674926160589      109  Add money           200              OK
# 529  1674926160699      118  Add money           200              OK
# 530  1674926160818      122  Add money           200              OK
# 531  1674926160940      119  Add money           200              OK
#
#     threadName dataType  success  failureMessage  bytes  sentBytes  \
# 0    Users 1-1     text     True             NaN    189        260
# ...

# %%
results['elapsed'].plot()
# Out:
# <AxesSubplot:>

# %%
results.boxplot(column='elapsed')
# Out:
# <AxesSubplot:>
